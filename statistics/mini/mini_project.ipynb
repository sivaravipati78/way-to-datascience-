# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
# Out:
# C:\Users\hi\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\hi\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\hi\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\hi\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df = pd.read_csv(r'C:\Users\hi\Desktop\dse\Stat\mini project\laliga.csv')
df.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0        Pos             Team    Seasons     Points  GamesPlayed   GamesWon
# 1          1      Real Madrid         86       4385         2762       1647
# 2          2        Barcelona         86       4262         2762       1581
# 3          3  Atletico Madrid         80       3442         2614       1241
# 4          4         Valencia         82       3386         2664       1187
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0  GamesDrawn  GamesLost   GoalsFor  GoalsAgainst    Champion   Runner-up
# 1         552        563       5947          3140          33          23
# 2         573        608       5900          3114          25          25
# 3         598        775       4534          3309          10           8
# 4         616        861       4398          3469           6           6
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 20 columns):
# Unnamed: 0     62 non-null object
# Unnamed: 1     62 non-null object
# Unnamed: 2     62 non-null object
# Unnamed: 3     62 non-null object
# Unnamed: 4     62 non-null object
# Unnamed: 5     62 non-null object
# Unnamed: 6     62 non-null object
# Unnamed: 7     62 non-null object
# Unnamed: 8     62 non-null object
# Unnamed: 9     62 non-null object
# Unnamed: 10    62 non-null object
# Unnamed: 11    62 non-null object
# Unnamed: 12    62 non-null object
# Unnamed: 13    62 non-null object
# Unnamed: 14    62 non-null object
# Unnamed: 15    62 non-null object
# Unnamed: 16    62 non-null object
# Unnamed: 17    62 non-null object
# Unnamed: 18    62 non-null object
# Unnamed: 19    62 non-null object
# dtypes: object(20)
# memory usage: 9.8+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Unnamed: 1     0
# Unnamed: 2     0
# Unnamed: 3     0
# Unnamed: 4     0
# Unnamed: 5     0
# Unnamed: 6     0
# Unnamed: 7     0
# Unnamed: 8     0
# Unnamed: 9     0
# Unnamed: 10    0
# Unnamed: 11    0
# Unnamed: 12    0
# Unnamed: 13    0
# Unnamed: 14    0
# Unnamed: 15    0
# Unnamed: 16    0
# Unnamed: 17    0
# Unnamed: 18    0
# Unnamed: 19    0
# dtype: int64

# %%
df.columns = df.iloc[0]
df.head()
# Out:
# 0  Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0  Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn
# 1    1      Real Madrid       86    4385         2762      1647         552
# 2    2        Barcelona       86    4262         2762      1581         573
# 3    3  Atletico Madrid       80    3442         2614      1241         598
# 4    4         Valencia       82    3386         2664      1187         616
#
# 0  GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 0  GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth
# 1        563      5947          3140        33         23      8       8
# 2        608      5900          3114        25         25     12      12
# 3        775      4534          3309        10          8     16       9
# 4        861      4398          3469         6          6     10      11
#
# 0  Fifth  Sixth   T    Debut  Since/LastApp  BestPosition
# ...

# %%
df = df.drop(df.index[0])
df.head()
# Out:
# 0 Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1   1      Real Madrid      86   4385        2762     1647        552
# 2   2        Barcelona      86   4262        2762     1581        573
# 3   3  Atletico Madrid      80   3442        2614     1241        598
# 4   4         Valencia      82   3386        2664     1187        616
# 5   5  Athletic Bilbao      86   3368        2762     1209        633
#
# 0 GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 1       563     5947         3140       33        23     8      8     3     4
# 2       608     5900         3114       25        25    12     12     4     6
# 3       775     4534         3309       10         8    16      9     7     6
# 4       861     4398         3469        6         6    10     11    10     7
# 5       920     4631         3700        8         7    10      5     8    10
#
# 0   T    Debut Since/LastApp BestPosition
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 1 to 61
# Data columns (total 20 columns):
# Pos              61 non-null object
# Team             61 non-null object
# Seasons          61 non-null object
# Points           61 non-null object
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runner-up        61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null object
# dtypes: object(20)
# memory usage: 10.0+ KB

# %%
df.tail()
# Out:
# 0  Pos              Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 57  57             Xerez       1     34          38        8         10
# 58  58            Condal       1     22          30        7          8
# 59  59   Atletico Tetuan       1     19          30        7          5
# 60  60  Cultural Leonesa       1     14          30        5          4
# 61  61            Girona       1      -           -        -          -
#
# 0  GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# 57        20       38           66        -         -     -      -     -
# 58        15       37           57        -         -     -      -     -
# 59        18       51           85        -         -     -      -     -
# 60        21       34           65        -         -     -      -     -
# 61         -        -            -        -         -     -      -     -
#
# 0  Sixth  T    Debut Since/LastApp BestPosition
# ...

# %%
df = df.replace('-',np.NaN)
df.tail()
# Out:
# 0  Pos              Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 57  57             Xerez       1     34          38        8         10
# 58  58            Condal       1     22          30        7          8
# 59  59   Atletico Tetuan       1     19          30        7          5
# 60  60  Cultural Leonesa       1     14          30        5          4
# 61  61            Girona       1    NaN         NaN      NaN        NaN
#
# 0  GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# 57        20       38           66      NaN       NaN   NaN    NaN   NaN
# 58        15       37           57      NaN       NaN   NaN    NaN   NaN
# 59        18       51           85      NaN       NaN   NaN    NaN   NaN
# 60        21       34           65      NaN       NaN   NaN    NaN   NaN
# 61       NaN      NaN          NaN      NaN       NaN   NaN    NaN   NaN
#
# 0  Sixth    T    Debut Since/LastApp BestPosition
# ...

# %%
df.shape
# Out:
# (61, 20)

# %%
df.head()
# Out:
# 0 Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1   1      Real Madrid      86   4385        2762     1647        552
# 2   2        Barcelona      86   4262        2762     1581        573
# 3   3  Atletico Madrid      80   3442        2614     1241        598
# 4   4         Valencia      82   3386        2664     1187        616
# 5   5  Athletic Bilbao      86   3368        2762     1209        633
#
# 0 GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 1       563     5947         3140       33        23     8      8     3     4
# 2       608     5900         3114       25        25    12     12     4     6
# 3       775     4534         3309       10         8    16      9     7     6
# 4       861     4398         3469        6         6    10     11    10     7
# 5       920     4631         3700        8         7    10      5     8    10
#
# 0   T    Debut Since/LastApp BestPosition
# ...

# %%
df.iloc[:,2:17]=df.iloc[:,2:17].astype(float)
df['BestPosition']=df['BestPosition'].astype(int)
df['Pos'] = df['Pos'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 1 to 61
# Data columns (total 20 columns):
# Pos              61 non-null int32
# Team             61 non-null object
# Seasons          61 non-null float64
# Points           60 non-null float64
# GamesPlayed      60 non-null float64
# GamesWon         60 non-null float64
# GamesDrawn       60 non-null float64
# GamesLost        60 non-null float64
# GoalsFor         60 non-null float64
# GoalsAgainst     60 non-null float64
# Champion         9 non-null float64
# Runner-up        13 non-null float64
# Third            18 non-null float64
# Fourth           22 non-null float64
# Fifth            25 non-null float64
# Sixth            28 non-null float64
# T                33 non-null float64
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int32
# dtypes: float64(15), int32(2), object(3)
# memory usage: 9.5+ KB

# %%
df.head()
# Out:
# 0  Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 1    1      Real Madrid     86.0  4385.0       2762.0    1647.0       552.0
# 2    2        Barcelona     86.0  4262.0       2762.0    1581.0       573.0
# 3    3  Atletico Madrid     80.0  3442.0       2614.0    1241.0       598.0
# 4    4         Valencia     82.0  3386.0       2664.0    1187.0       616.0
# 5    5  Athletic Bilbao     86.0  3368.0       2762.0    1209.0       633.0
#
# 0  GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 1      563.0    5947.0        3140.0      33.0       23.0    8.0     8.0
# 2      608.0    5900.0        3114.0      25.0       25.0   12.0    12.0
# 3      775.0    4534.0        3309.0      10.0        8.0   16.0     9.0
# 4      861.0    4398.0        3469.0       6.0        6.0   10.0    11.0
# 5      920.0    4631.0        3700.0       8.0        7.0   10.0     5.0
#
# 0  Fifth  Sixth     T    Debut Since/LastApp  BestPosition
# ...

# %%
df['Seasons'].isnull().sum()
# Out:
# 0

# %%
df['Seasons'] = df['Seasons'].astype(int)

# %%
df[df['Points'].isnull()]
# Out:
# 0   Pos    Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 61   61  Girona        1     NaN          NaN       NaN         NaN
#
# 0   GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 61        NaN       NaN           NaN       NaN        NaN    NaN     NaN
#
# 0   Fifth  Sixth   T    Debut Since/LastApp  BestPosition
# 61    NaN    NaN NaN  2017-18       2017-18             9

# %%
df = df[df['Points'].notnull()]
df['Points'] = df['Points'].astype(int)
df.head()
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0  Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 1    1      Real Madrid       86    4385       2762.0    1647.0       552.0
# 2    2        Barcelona       86    4262       2762.0    1581.0       573.0
# 3    3  Atletico Madrid       80    3442       2614.0    1241.0       598.0
# 4    4         Valencia       82    3386       2664.0    1187.0       616.0
# 5    5  Athletic Bilbao       86    3368       2762.0    1209.0       633.0
#
# 0  GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 1      563.0    5947.0        3140.0      33.0       23.0    8.0     8.0
# ...

# %%
df.iloc[:,4:10] = df.iloc[:,4:10].astype(int)
df.head()
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 0  Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 1    1      Real Madrid       86    4385         2762      1647         552
# 2    2        Barcelona       86    4262         2762      1581         573
# 3    3  Atletico Madrid       80    3442         2614      1241         598
# 4    4         Valencia       82    3386         2664      1187         616
# 5    5  Athletic Bilbao       86    3368         2762      1209         633
#
# 0  GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# ...

# %%
df['Champion']=df['Champion'].fillna(0)
df['Champion'] = df['Champion'].astype(int)
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.iloc[:,10:17] = df.iloc[:,10:17].fillna(0)
df.iloc[:,10:17] = df.iloc[:,10:17].astype(int)
df.head()
# Out:
# 0  Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 1    1      Real Madrid       86    4385         2762      1647         552
# 2    2        Barcelona       86    4262         2762      1581         573
# 3    3  Atletico Madrid       80    3442         2614      1241         598
# 4    4         Valencia       82    3386         2664      1187         616
# 5    5  Athletic Bilbao       86    3368         2762      1209         633
#
# 0  GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 1        563      5947          3140        33         23      8       8
# 2        608      5900          3114        25         25     12      12
# 3        775      4534          3309        10          8     16       9
# 4        861      4398          3469         6          6     10      11
# 5        920      4631          3700         8          7     10       5
#
# 0  Fifth  Sixth   T    Debut Since/LastApp  BestPosition
# ...

# %%
df['Debut']=df['Debut'].str[:4].astype(int)
df['Since/LastApp'] = df['Since/LastApp'].str[:4].astype(int)
df.head()
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0  Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 1    1      Real Madrid       86    4385         2762      1647         552
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 1 to 60
# Data columns (total 20 columns):
# Pos              60 non-null int32
# Team             60 non-null object
# Seasons          60 non-null int32
# Points           60 non-null int32
# GamesPlayed      60 non-null int32
# GamesWon         60 non-null int32
# GamesDrawn       60 non-null int32
# GamesLost        60 non-null int32
# GoalsFor         60 non-null int32
# GoalsAgainst     60 non-null int32
# Champion         60 non-null int32
# Runner-up        60 non-null int32
# Third            60 non-null int32
# Fourth           60 non-null int32
# Fifth            60 non-null int32
# Sixth            60 non-null int32
# T                60 non-null int32
# Debut            60 non-null int32
# Since/LastApp    60 non-null int32
# BestPosition     60 non-null int32
# dtypes: int32(19), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# ###### 1.	Which are the teams which started playing between 1930-1980?

# %%
df[(df['Debut']>=1930) & (df['Debut']<=1980)][['Team','Debut']]
# Out:
# 0                  Team  Debut
# 4              Valencia   1931
# 6               Sevilla   1934
# 9              Zaragoza   1939
# 10           Real Betis   1932
# 11  Deportivo La Coruna   1941
# 12           Celta Vigo   1939
# 13           Valladolid   1948
# 15       Sporting Gijon   1944
# 16              Osasuna   1935
# 17               Malaga   1949
# 18               Oviedo   1933
# 19             Mallorca   1960
# 20           Las Palmas   1951
# 22              Granada   1941
# 23       Rayo Vallecano   1977
# 24                Elche   1959
# 26             Hercules   1935
# 27             Tenerife   1961
# 28               Murcia   1940
# 29               Alaves   1930
# 30              Levante   1963
# 31            Salamanca   1974
# 32             Sabadell   1943
# 33                Cadiz   1977
# 35            Castellon   1941
# 38              Cordoba   1962
# 40           Recreativo   1978
# 41            Burgos CF   1971
# 42           Pontevedra   1963
# ...

# %%
df[(df['Debut']>=1930) & (df['Debut']<=1980)].count()['Team']
# Out:
# 37

# %% [markdown]
# ###### so there totaly 37 teams are statred playing between 1930 to 1980

# %% [markdown]
# #### 2.	Which are the top 5 teams in terms of points?

# %%
df.nlargest(5,'T')[['Team','T']]
# Out:
# 0             Team   T
# 2        Barcelona  83
# 1      Real Madrid  79
# 3  Atletico Madrid  56
# 4         Valencia  50
# 5  Athletic Bilbao  49

# %% [markdown]
# ##### 3.	What is the distribution of the winning percentage for all teams? Which teams are in the top 5 in terms of winning percentage? (Winning percentage= (GamesWon / GamesPlayed)*100)

# %%
df['Winning_percentage'] =  round((df['GamesWon']/df['GamesPlayed'])*100)
df.nlargest(5,'Winning_percentage')[['Team','Winning_percentage']]
# Out:
# 0             Team  Winning_percentage
# 1      Real Madrid                60.0
# 2        Barcelona                57.0
# 3  Atletico Madrid                47.0
# 4         Valencia                45.0
# 5  Athletic Bilbao                44.0

# %% [markdown]
# #### 4.	Is there a significant difference in the winning percentage for teams which have attained a best position between 1-3 and those teams which have had a best position between 4-7.

# %%
df['Rank'] = df['Winning_percentage'].rank(method='min',ascending=False)

# %%
df[df['Rank']<=3]['Winning_percentage'].skew()
# Out:
# -1.361301396376004

# %%
df[(df['Rank']>=4) & (df['Rank']<=7)]['Winning_percentage'].skew()
# Out:
# 0.19973522061815654

# %%
df[df['Rank']<=3]['Winning_percentage'].std()
# Out:
# 6.8068592855540455

# %%
df[(df['Rank']>=4) & (df['Rank']<=7)]['Winning_percentage'].std()
# Out:
# 2.0615528128088303

# %%
sns.distplot(df[df['Rank']<=3]['Winning_percentage'])
sns.distplot(df[(df['Rank']>=4) & (df['Rank']<=7)]['Winning_percentage'])
plt.show()

# %% [markdown]
# ##### 2. A study was done to measure the blood pressure of 60 year old women with glaucoma. A random sample of 200 60-year old women with glaucoma was chosen. The mean of the systolic blood pressure in the sample was 140 mm Hg and the standard deviation was 25 mm Hg.

# %%
# given

n = 200
xbar = 140 # sample mean
s = 25 # sample std

# %% [markdown]
# ###### a)	Calculate the estimated standard error of the sample mean? What does the standard error indicate?

# %%
std_error = s/np.sqrt(n)
print('std error of sample mean ',std_error)
# Out:
# std error of sample mean  1.7677669529663687

# %% [markdown]
# ###### b)	Estimate a 95% confidence interval for the true mean blood pressure for all 60-year old women with glaucoma.

# %%
t_alpha_by_2 = st.t.isf(0.025,n-1)
ME = t_alpha_by_2*std_error
uci = xbar+ME
lci = xbar-ME
print('t_alpha_by_2 ',t_alpha_by_2)
print('point_estimation ',xbar)
print('margin_of_error ',ME)
print('upper_confidence_interval ',uci)
print('lowwer_confidence_interval ',lci)
# Out:
# t_alpha_by_2  1.9719565442493954
# point_estimation  140
# margin_of_error  3.485959611609844
# upper_confidence_interval  143.48595961160984
# lowwer_confidence_interval  136.51404038839016

# %% [markdown]
# ###### c)	Assume that instead of 200, a random sample of only 100 60-year old women with glaucoma was chosen. The sample mean and standard deviation estimates are the same as those in the original study. What is the estimated 95% confidence interval for the true mean blood pressure?

# %%
n = 100
xbar = 140
s = 25
std_error = s/np.sqrt(n)
t_alpha_by_2 = st.t.isf(0.025,n-1)
ME = t_alpha_by_2*std_error
uci = xbar+ME
lci = xbar-ME
print('std error of sample mean ',std_error)
print('t_alpha_by_2 ',t_alpha_by_2)
print('point_estimation ',xbar)
print('margin_of_error ',ME)
print('upper_confidence_interval ',uci)
print('lowwer_confidence_interval ',lci)
# Out:
# std error of sample mean  2.5
# t_alpha_by_2  1.9842169515086832
# point_estimation  140
# margin_of_error  4.960542378771708
# upper_confidence_interval  144.96054237877172
# lowwer_confidence_interval  135.03945762122828

# %% [markdown]
# ###### d)	Which of the two above intervals are wider?

# %% [markdown]
# from above we can observe that sample size 100 having wider range of critical limit of (135.04 - 144.96),
# where as sample size of 200 having (136.51 - 143.49).
# so from above we observe that as sample size increase range is getting striking towards the mean

# %% [markdown]
# ###### e)	Explain in non-technical terms why the estimated standard error of a sample mean tends to decrease with an increase in sample size.

# %% [markdown]
# since when sample size increase it tends near or equal to population, so where the error also getting reduce

# %%
df1 = pd.read_csv(r'C:\Users\hi\Desktop\dse\Stat\mini project\Golf.csv')
df1.head()
# Out:
#    Current  New
# 0      264  277
# 1      261  269
# 2      267  263
# 3      272  266
# 4      258  262

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
# Current    40 non-null int64
# New        40 non-null int64
# dtypes: int64(2)
# memory usage: 768.0 bytes

# %%
df1.describe()
# Out:
#           Current         New
# count   40.000000   40.000000
# mean   270.275000  267.500000
# std      8.752985    9.896904
# min    255.000000  250.000000
# 25%    263.000000  262.000000
# 50%    270.000000  265.000000
# 75%    275.250000  274.500000
# max    289.000000  289.000000

# %% [markdown]
# ###### 2.	Analyze the data to provide the hypothesis testing conclusion. What is the p-value for your test? What is your recommendation for Par Inc.?

# %%
#H0 current = new
#H1 current != new
alpha = 0.05
st.ttest_rel(df1['Current'],df1['New'])
# Out:
# Ttest_relResult(statistic=1.2769699827911767, pvalue=0.20916361823147053)

# %% [markdown]
# ###### since P-value  greater than alpha we acpect the H0 where cuurrent  = new, so new ball is not diff from current ball

# %% [markdown]
# ###### 3.	What is the 95% confidence interval for the population mean of each model, and what is the 95% confidence interval for the difference between the means of the two population?

# %%
# for current
n = 40
xbar = np.mean(df1['Current'])
s = np.std(df1['Current'])
std_error = s/np.sqrt(n)
t_alpha_by_2 = st.t.isf(0.025,n-1)
ME = t_alpha_by_2*std_error
uci = xbar+ME
lci = xbar-ME
print('sample_mean ',xbar)
print('std error of sample mean ',std_error)
print('t_alpha_by_2 ',t_alpha_by_2)
print('point_estimation ',xbar)
print('margin_of_error ',ME)
print('upper_confidence_interval ',uci)
print('lowwer_confidence_interval ',lci)
# Out:
# sample_mean  270.275
# std error of sample mean  1.3665593199711457
# t_alpha_by_2  2.0226909117347285
# point_estimation  270.275
# margin_of_error  2.764127116852027
# upper_confidence_interval  273.039127116852
# lowwer_confidence_interval  267.51087288314795

# %%
# for New
n = 40
xbar = np.mean(df1['New'])
s = np.std(df1['New'])
std_error = s/np.sqrt(n)
t_alpha_by_2 = st.t.isf(0.025,n-1)
ME = t_alpha_by_2*std_error
uci = xbar+ME
lci = xbar-ME
print('sample_mean ',xbar)
print('std error of sample mean ',std_error)
print('t_alpha_by_2 ',t_alpha_by_2)
print('point_estimation ',xbar)
print('margin_of_error ',ME)
print('upper_confidence_interval ',uci)
print('lowwer_confidence_interval ',lci)
# Out:
# sample_mean  267.5
# std error of sample mean  1.5451537140362444
# t_alpha_by_2  2.0226909117347285
# point_estimation  267.5
# margin_of_error  3.125368374614273
# upper_confidence_interval  270.62536837461425
# lowwer_confidence_interval  264.37463162538575

# %% [markdown]
# for 95% confidence we observe  that for Current model ball range are (267.51 - 273.04)
#
# whereas for New model ball range are (264.37 - 270.63)
