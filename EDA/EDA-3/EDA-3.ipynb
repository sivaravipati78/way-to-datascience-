# %%
bivariant and multi varaint analysis
# Out:
#   File "<ipython-input-1-a25669de96d6>", line 1
#     bivariant and multi varaint analysis
#                               ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
plt.scatter(df.total_bill,df.tip)
plt.title('total_bill vs tip')
plt.show()

# %%
df.plot(x ='total_bill',y ='tip', kind = 'scatter')
plt.show()

# %%
sns.jointplot(x ='total_bill',y ='tip',data = df )
plt.show()
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [raw]
# 2 and 3 $ is the highest frequency we can observe.

# %%
sns.jointplot(x ='total_bill',y ='tip',data = df,kind = 'reg' )
plt.show()

# %%
sns.jointplot(x ='total_bill',y ='tip',data = df,kind = 'hex' )
plt.show()
sns.jointplot(x ='total_bill',y ='tip',data = df,kind = 'kde' )
plt.show()

# %%
sns.lmplot(x ='total_bill',y ='tip',data = df)
#sns.set(palette='spring')
plt.show()

# %%
sns.lmplot(x ='total_bill',y ='tip',data = df,fit_reg=False, hue = 'day',palette='spring'
)
plt.show()
sns.lmplot(x ='total_bill',y ='tip',data = df,fit_reg=False, hue = 'sex',markers = ['x','o']
)
plt.show()

# %%
sns.lmplot(x ='total_bill',y ='tip',data = df,fit_reg=False, hue = 'sex',markers = ['x','o'],row = 'time')
plt.show()
sns.lmplot(x ='total_bill',y ='tip',data = df,fit_reg=False, hue = 'sex',markers = ['x','o'],col = 'day')
plt.show()

# %%
sns.lmplot(x ='total_bill',y ='tip',data = df,fit_reg=False,hue = 'sex',markers = ['x','o'],row='smoker',col = 'day')
plt.show()

# %%
sns.lmplot(x ='total_bill',y ='tip',data = df,fit_reg=False,hue = 'sex',markers = ['x','o'],row='smoker',col = 'time')
plt.show()

# %%
smoker are more scattered , but non smokers are in a correlation, 
so if we build a model , our model workd better with non smokers than smokers.

# %%
sns.stripplot(x ='day',y ='total_bill',data = df,)#jitter = False 
#for getting 20 $ denomination in a day , we can use stripplot or swarm plot.

# %%
sns.swarmplot(x ='day',y ='total_bill',data = df,)# points dont overlap in swarmplot as in strip plot.

# %%
sns.boxplot(x ='day',y ='total_bill',data = df,)
plt.show()
sns.boxplot(x ='smoker',y ='total_bill',data = df,hue = 'day')
plt.show()

# %%
sns.violinplot(x ='day',y ='total_bill',data = df,hue = 'smoker')
plt.show()

# %%
sns.violinplot(x ='day',y ='total_bill',data = df,hue = 'smoker',split=True)
plt.show()
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.pairplot(df)

# %%
the size with 3 gave more tip,.

# %%
avg = df.total_bill.groupby(df.sex).apply(np.mean)
avg
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
df.total_bill.groupby(df.sex).apply(np.mean).plot(kind = 'bar')
plt.show()

# %%
avg.index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, name='sex', dtype='category')

# %%
#avg.value_counts().plot(kind = 'bar')
plt.bar(avg.index,avg.values,color =['r','b'])
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['size'].sum()

#da.apply(1/)
# Out:
# 627

# %%
dfp = df.groupby('day').apply(np.sum)['size']
dfp
# Out:
# day
# Thur    152
# Fri      40
# Sat     219
# Sun     216
# Name: size, dtype: int64

# %%
dffp =dfp*100/(df['size'].sum())
dffp
# Out:
# day
# Thur    24.242424
# Fri      6.379585
# Sat     34.928230
# Sun     34.449761
# Name: size, dtype: float64

# %%
dffp.index
plt.bar(dffp.index,dffp.values,color = ['r','g','b','k'])
plt.ylabel('percentage of people')
plt.xlabel('day')
plt.show()

# %%
(df['day'].value_counts(normalize = True)*100).plot(kind ='bar')

# %%
df.groupby(['sex','smoker']).count()['total_bill']['Male'].plot(kind ='bar')
plt.show()
df.groupby(['sex','smoker']).count()['total_bill']['Male'].plot(kind ='pie',autopct='%1.2f%%')
plt.show()

# %%
df['smoker'][df['sex'] =='Male'].value_counts()
# Out:
# No     97
# Yes    60
# Name: smoker, dtype: int64

# %%
pd.crosstab(index= df['sex'],columns ='count')# one way table.
# Out:
# col_0   count
# sex
# Male      157
# Female     87

# %%
pd.crosstab(index= df['sex'],columns =df['day'])# two way table
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      30   10   59   58
# Female    32    9   28   18

# %%
a =pd.crosstab(index= df['sex'],columns =df['day'])# two way table
print(a)
a.plot(kind ='bar',stacked =False)
plt.show()
a.plot(kind ='bar',stacked =True)
plt.show()
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      30   10   59   58
# Female    32    9   28   18

# %%
a1 =pd.crosstab(index= df['smoker'],columns =df['day'])

# %%
a1.plot(kind ='bar')

# %%
ddf =pd.DataFrame({'Data': [1,2,3,1,2,3,1,2,3,1,2,3],
                   'value' :np.random.randn(12),
                   'variable' :['A','A','A','B','B','B','c','c','c','d','d','d']})

# %%
ddf.head()
# Out:
#    Data     value variable
# 0     1 -0.296263        A
# 1     2  0.748648        A
# 2     3 -2.824039        A
# 3     1 -1.139036        B
# 4     2  0.090816        B

# %%
ddf.pivot('Data','variable','value')# when we dont have duplicates in index and col it will work.
# Out:
# variable         A         B         c         d
# Data
# 1        -0.296263 -1.139036 -0.324840 -1.018343
# 2         0.748648  0.090816 -1.418512  1.505128
# 3        -2.824039 -0.316571  0.331298 -0.791527

# %%
df.pivot_table(index ='sex',columns ='day',values = 'size',aggfunc ='sum')
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      73   21  156  163
# Female    79   19   63   53

# %% [markdown]
# ## Dealing with catagorical data:

# %% [markdown]
# label encoding

# %%
df['gender'] =df.sex.replace({'Male':0,'Female':1})
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  gender
# 0       16.99  1.01  Female     No  Sun  Dinner     2       1
# 1       10.34  1.66    Male     No  Sun  Dinner     3       0
# 2       21.01  3.50    Male     No  Sun  Dinner     3       0
# 3       23.68  3.31    Male     No  Sun  Dinner     2       0
# 4       24.59  3.61  Female     No  Sun  Dinner     4       1

# %%
df['gender2'] = df.sex.map({'Male':0,'Female':1})
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  gender  gender2
# 0       16.99  1.01  Female     No  Sun  Dinner     2       1        1
# 1       10.34  1.66    Male     No  Sun  Dinner     3       0        0
# 2       21.01  3.50    Male     No  Sun  Dinner     3       0        0
# 3       23.68  3.31    Male     No  Sun  Dinner     2       0        0
# 4       24.59  3.61  Female     No  Sun  Dinner     4       1        1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lr = LabelEncoder()
df['le'] =lr.fit_transform(df['day'])
df['le'].value_counts()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  gender  gender2  le
# 0       16.99  1.01  Female     No  Sun  Dinner     2       1        1   2
# 1       10.34  1.66    Male     No  Sun  Dinner     3       0        0   2
# 2       21.01  3.50    Male     No  Sun  Dinner     3       0        0   2
# 3       23.68  3.31    Male     No  Sun  Dinner     2       0        0   2
# 4       24.59  3.61  Female     No  Sun  Dinner     4       1        1   2

# %% [markdown]
# ## onehot encoding

# %%
df['dummysex'] =pd.get_dummies(df['sex'],drop_first=True)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  gender  gender2  le  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2       1        1   2
# 1       10.34  1.66    Male     No  Sun  Dinner     3       0        0   2
# 2       21.01  3.50    Male     No  Sun  Dinner     3       0        0   2
# 3       23.68  3.31    Male     No  Sun  Dinner     2       0        0   2
# 4       24.59  3.61  Female     No  Sun  Dinner     4       1        1   2
#
#    dummysex
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
pd.get_dummies(df,columns =['sex'])
# Out:
#      total_bill   tip smoker   day    time  size  gender  gender2  le  \
# 0         16.99  1.01     No   Sun  Dinner     2       1        1   2
# 1         10.34  1.66     No   Sun  Dinner     3       0        0   2
# 2         21.01  3.50     No   Sun  Dinner     3       0        0   2
# 3         23.68  3.31     No   Sun  Dinner     2       0        0   2
# 4         24.59  3.61     No   Sun  Dinner     4       1        1   2
# 5         25.29  4.71     No   Sun  Dinner     4       0        0   2
# 6          8.77  2.00     No   Sun  Dinner     2       0        0   2
# 7         26.88  3.12     No   Sun  Dinner     4       0        0   2
# 8         15.04  1.96     No   Sun  Dinner     2       0        0   2
# 9         14.78  3.23     No   Sun  Dinner     2       0        0   2
# 10        10.27  1.71     No   Sun  Dinner     2       0        0   2
# 11        35.26  5.00     No   Sun  Dinner     4       1        1   2
# ...

# %%
dm =pd.get_dummies(df['sex'],drop_first=True)
pd.concat([df,dm])
# Out:
#      Female  day  dummysex  gender  gender2   le     sex  size smoker    time  \
# 0       NaN  Sun       1.0     1.0      1.0  2.0  Female   2.0     No  Dinner
# 1       NaN  Sun       0.0     0.0      0.0  2.0    Male   3.0     No  Dinner
# 2       NaN  Sun       0.0     0.0      0.0  2.0    Male   3.0     No  Dinner
# 3       NaN  Sun       0.0     0.0      0.0  2.0    Male   2.0     No  Dinner
# 4       NaN  Sun       1.0     1.0      1.0  2.0  Female   4.0     No  Dinner
# 5       NaN  Sun       0.0     0.0      0.0  2.0    Male   4.0     No  Dinner
# 6       NaN  Sun       0.0     0.0      0.0  2.0    Male   2.0     No  Dinner
# 7       NaN  Sun       0.0     0.0      0.0  2.0    Male   4.0     No  Dinner
# 8       NaN  Sun       0.0     0.0      0.0  2.0    Male   2.0     No  Dinner
# 9       NaN  Sun       0.0     0.0      0.0  2.0    Male   2.0     No  Dinner
# 10      NaN  Sun       0.0     0.0      0.0  2.0    Male   2.0     No  Dinner
# ...
