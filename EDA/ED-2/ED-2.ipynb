# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# <h4>univariant analysis:</h4>
#     <p>
#       If data is numerical
#        1. histogram----------continous interval(equal bins , uneual bins).
#        2. kernal density plot or distribution plot.
#        3. box plot.
#        4. violin plot.
#        5. bargraph ----x -catagary, y- counts
#        6. pie chart --x -catagary, y- counts (preferred in tablue showing)
#        </p>

# %%
df1 = sns.load_dataset('tips')
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
df1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
print('avg bill paid by all              : ',df1.total_bill.mean())
print('25th percentile of total bill paid: ',df1.total_bill.quantile(0.25))
print('50th percentile of total bill paid: ',df1.total_bill.quantile(0.5))
print('variance of bill paid by all      : ',df1.total_bill.var())
print('std deveation bill paid by all    : ',df1.total_bill.std())
print('IQRof  bill paid by all           : ',df1.total_bill.quantile(0.75)-df1.total_bill.quantile(0.25))
print('min bill paid by all    : ',df1.total_bill.min())

print('max bill paid by all    : ',df1.total_bill.max())
# Out:
# avg bill paid by all              :  19.785942622950824
# 25th percentile of total bill paid:  13.3475
# 50th percentile of total bill paid:  17.795
# variance of bill paid by all      :  79.25293861397826
# std deveation bill paid by all    :  8.902411954856856
# IQRof  bill paid by all           :  10.779999999999998
# min bill paid by all    :  3.07
# max bill paid by all    :  50.81

# %%
plt.hist(df1.total_bill,color='r',bins =6,rwidth=.95)# default bins =10
plt.show()
plt.hist(df1.total_bill,bins =[0,10,25,30,35,45,50],rwidth=.95)# custimised bins
plt.show()
df1.total_bill.plot(kind = 'hist',color = 'g',rwidth=.95)
plt.show()
df1.total_bill.plot(kind = 'hist',color = 'g',rwidth=.95,orientation = 'horizontal')
plt.show()

# %%
#sns.# there is no histogram in seaborn.

# %%
sns.distplot(df1.total_bill,hist=True, kde=True, rug=False)
plt.axvline(df1.total_bill.mean())
plt.axvline(df1.total_bill.median(),color ='r')
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df1.total_bill.plot(kind = 'kde')   # due to different scaling we are not able view the kde plot
df1.total_bill.plot(kind = 'hist')
plt.show()

# %%
plt.boxplot(df1.total_bill)

plt.show()
df1.total_bill.plot(kind = 'box')

# %%
sns.boxplot(df1.total_bill)

# %%
sns.violinplot(df1.total_bill)
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df1.total_bill[df1.total_bill>41].count()
# Out:
# 8

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
df1['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
df1['time'].unique()
# Out:
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
df1['sex'].unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
df1['smoker'].unique()
# Out:
# [No, Yes]
# Categories (2, object): [No, Yes]

# %%
y =df1['sex'].value_counts()
y
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
s =df1['sex'].value_counts()
s.index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category')

# %%
df1.sex.unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
plt.bar(df1['sex'].value_counts().index,df1['sex'].value_counts().values)
plt.show()

# %%
plt.bar(df1.day.value_counts().index,df1.day.value_counts().values)
plt.xticks(rotation=0)# for rotating labels
plt.show()
df1.day.value_counts().plot(kind = 'bar')
plt.xticks(rotation=0)# for rotating labels

plt.show()

# %%
sns.countplot(df1['day'])
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, .5, .5], aspect=1)
ax1.pie(df1['day'].value_counts().values,labels =df1['day'].value_counts().index,radius =1.2)
#plt.show()
ax2 = fig.add_axes([.4, .0, .5, .5], aspect=1)

ax2.pie(df1['day'].value_counts().values,labels =df1['day'].value_counts().index,autopct='%1.2f',radius =1.2)
#plt.show()
ax3 = fig.add_axes([.25, -.5, .5, .5], aspect=1)

ax3.pie(df1['day'].value_counts().values,labels =df1['day'].value_counts().index,autopct='%1.2f',explode=[0.1,0,0,0],radius =1.2)
plt.show()

# %%
df1['day'].value_counts().plot(kind ='pie')

# %%
fig,axes =plt.subplots(2,2,figsize=(15,5))
axes[0,0].bar(df1.day.value_counts().index,df1.day.value_counts().values)# for plt
df1['day'].value_counts().plot(kind ='pie',ax =axes[0,1])               # for plot
df1['day'].value_counts().plot(kind ='bar',ax =axes[1,0])                              
plt.show()

# %%
fig,axes = plt.subplots(2,2,figsize=(18,9))
axes[0,0].bar(df1.day.value_counts().index,df1.day.value_counts().values)
axes[0,1].bar(df1.time.value_counts().index,df1.time.value_counts().values)
axes[1,0].bar(df1.smoker.value_counts().index,df1.smoker.value_counts().values)
axes[1,1].bar(df1.sex.value_counts().index,df1.sex.value_counts().values)
axes[0,0].set_title('Bargraph for day')
axes[0,1].set_title('Bargraph for time')
axes[1,0].set_title('Bargraph for smoker')
axes[1,1].set_title('Bargraph for sex')
plt.show()

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig,axes = plt.subplots(2,2,figsize=(18,9))
axes[0,0].bar(df1.day.value_counts().index,df1.day.value_counts().values)
axes[0,1].bar(df1.time.value_counts().index,df1.time.value_counts().values)
axes[1,0].bar(df1.smoker.value_counts().index,df1.smoker.value_counts().values)
axes[1,1].bar(df1.sex.value_counts().index,df1.sex.value_counts().values)
axes[0,0].set_title('Bargraph for day')
axes[0,1].set_title('Bargraph for time')
axes[1,0].set_title('Bargraph for smoker')
axes[1,1].set_title('Bargraph for sex')
plt.show()

# %% [markdown]
# #scaling and transformation:

# %%
 xm =df1.total_bill.mean()

# %%
sd =df1.total_bill.std()

# %%
df2 =(df1.total_bill -xm)/sd

# %%
df2.head()
# Out:
# 0   -0.314066
# 1   -1.061054
# 2    0.137497
# 3    0.437416
# 4    0.539635
# Name: total_bill, dtype: float64

# %%
fig,axes = plt.subplots(1,3,figsize =(15,5))
df2.plot(kind = 'kde', ax = axes[0])
#plt.show()
df1.total_bill.plot(kind = 'kde', ax = axes[1])
sns.distplot(df2,ax =axes[2])# sameas first one
plt.show()
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print(df2.std())
print(df3.std())

print(df1.total_bill.std())
# Out:
# 1.0
# 0.18647699947333174
# 8.902411954856856

# %%
print(round(df2.mean()))
print(df3.mean())

print(df1.total_bill.mean())
# Out:
# 0
# 0.35014542570068735
# 19.785942622950824

# %%
print(df2.skew())
print(df3.skew())

print(df1.total_bill.skew())
# Out:
# 1.1332130376158207
# 1.1332130376158203
# 1.1332130376158205

# %%
print(df2.kurt())
print(df3.kurt())

print(df1.total_bill.kurt())
# Out:
# 1.2184840156638828
# 1.2184840156638836
# 1.2184840156638854

# %%
df3 = (df1.total_bill- df1.total_bill.min())/(df1.total_bill.max()- df1.total_bill.min())

# %%
fig,axes = plt.subplots(1,3,figsize =(15,5))
df3.plot(kind = 'kde', ax = axes[0])
#plt.show()
df1.total_bill.plot(kind = 'kde', ax = axes[1])
sns.distplot(df2,ax =axes[2])# sameas first one

plt.show()

# %% [raw]
# in minmax or normalised sacling we get min =0 and max =1
#
# but in standardisation we get mean =0 and std dev =1.

# %% [raw]
# Transformation

# %%
from math import sqrt
import math
df4 =df1.total_bill.apply(sqrt)

# %%
df5 =df1.total_bill.apply(math.log)

# %%
fig,axes = plt.subplots(1,3,figsize =(15,5))
df4.plot(kind = 'kde', ax = axes[0])#sqrt
#plt.show()
df1.total_bill.plot(kind = 'kde', ax = axes[1])
sns.distplot(df5,ax =axes[2])# log
axes[0].set_title('sqrt')
axes[1].set_title('default')
axes[2].set_title('log')

plt.show()

# %%
print(df4.skew())
print(df5.skew())
print(df1.total_bill.skew())
# Out:
# 0.5661281592596766
# -0.11623079290253824
# 1.1332130376158205

# %%
print(df4.kurt())
print(df5.kurt())
print(df1.total_bill.kurt())
# Out:
# 0.19520953466627722
# 0.4734793671474513
# 1.2184840156638854

# %%
s ={30, 29, 39, 39, 35, 44, 40, 43, 44, 52}

# %%
s
# Out:
# {29, 30, 35, 39, 40, 43, 44, 52}

# %%
import statistics 
l =[81, 62, 85, 65, 76, 86, 78, 80, 87]
statistics.mean(l)
# Out:
# 77.77777777777777
