# %% [markdown]
# # Python Day1

# %% [markdown]
# <h1 ><center> python</center></h1>

# %% [markdown]
# #### to give diff heading lengths-Heading

# %% [raw]
# Data science is a multi-disciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from structured and unstructured data.[1][2] Data science is related to data mining and big data.
#
# Data science is a "concept to unify statistics, data analysis, machine learning and their related methods" in order to "understand and analyze actual phenomena" with data.[3] It employs techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, and information science. Turing award winner Jim Gray imagined data science as a "fourth paradigm" of science (empirical, theoretical, computational and now data-driven) and asserted that "everything about science is changing because of the impact of information technology" and the data deluge.[4][5] In 2015, the American Statistical Association identified database management, statistics and machine learning, and distributed and parallel systems as the three emerging foundational professional communities.[6]
#
#
# ---to paste some raw content exactly without changing the format.

# %% [markdown]
# # phase1

# %% [markdown]
# make it markdown and then paste the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a =10
b =20
c = a+b
c
# Out:
# 30

# %%
a =10
a
# Out:
# 10

# %%
#comment

# %%
#control   ctrl+/ forward slash same to uncomment
# get inputs
# get inputs
# get inputs
# get inputs
# get inputs
# get inputs
# get inputs
# get inputs
# get inputs

# %%
'''
this
is python multi line comment
'''
# Out:
# '\nthis\nis python multi line comment\n'

# %% [markdown]
# # print

# %%
print("my python class!!!")# case sensitive
# Out:
# my python class!!!

# %%
print("my python class!!!")
# Out:
# my python class!!!

# %% [markdown]
# ### mutilple print statements

# %%
print("my python class!!!")
print("my python class!!!")
# Out:
# my python class!!!
# my python class!!!

# %%
print("my python class!!! \n")
print("my python class!!!")
# Out:
# my python class!!!
#
# my python class!!!

# %%
print("my python class!!! \t")
print("my python class!!!")
# Out:
# my python class!!!
# my python class!!!

# %%
print("my python class!!!\tmy python class!!!") # giving some space
# Out:
# my python class!!!	my python class!!!

# %%
print("my python class!!!\nmy python class!!!") # giving some space
# Out:
# my python class!!!
# my python class!!!

# %% [markdown]
# ### newline

# %%
print("my python class!!!\nmy python class!!!")
# Out:
# my python class!!!
# my python class!!!

# %%
print("my syntax error of EOL') 
# we cannot execute one double quote and one single quote.
# Out:
#   File "<ipython-input-1-844ef83e7be0>", line 1
#     print("my syntax error of EOL')
#                                    ^
# SyntaxError: EOL while scanning string literal

# %%
a = 10
a
print("value of a is ",a)
# Out:
# value of a is  10

# %%
print('\\n')
# Out:
# \n

# %%
name = "Siva"
age = 26
height = 5.10
marital_status = False # no space in variables.
type(marital_status), type(age)
# Out:
# (bool, int)

# %%
print("name :",name)
print("age :",age)
print("height : ",height)
print("marital_status : ",marital_status)
# Out:
# name : Siva
# age : 26
# height :  5.1
# marital_status :  False

# %% [markdown]
# <h5> printing  </h5>

# %%
Employee_name = "GL"
Employee_id = 100
Dept= "cse"
Email= "siva.ramkrish999@gmail.com"
contact = '044 23412345'
Age = 25 
height = 5.10
weight = 72
salary =50000
city = "chennai"

# %%
print("Employee_name :",Employee_name)
print("Employee_id :",Employee_id)
print("Dept :",Dept)
print("Email :",Email)
print("contact :",contact)
print("Age :",Age)
print("height :",height)
print("weight :",weight)
print("salary :",salary)
print("city :",city)
# Out:
# Employee_name : GL
# Employee_id : 100
# Dept : cse
# Email : siva.ramkrish999@gmail.com
# contact : 044 23412345
# Age : 25
# height : 5.1
# weight : 72
# salary : 50000
# city :  chennai

# %%
i,j,k = 1,2,3
print(i,j,k)
# Out:
# 1 2 3

# %%
x=y=z =10
print("x",x)
print("y",y)
print("z",z)
# Out:
# x 10
# y 10
# z 10

# %% [markdown]
# ## Type casting

# %%
k = 4.5
print(type(k))
# Out:
# <class 'float'>

# %%
int(k)
# Out:
# 4

# %%
print(type(k))
# Out:
# <class 'float'>

# %%
k
# Out:
# 4.5

# %%
k = int(k)

# %%
k
# Out:
# 4

# %%
i = 100
x = float(i)
y = str(i)

# %%
print(x,y)
# Out:
# 100.0 100

# %%
type(y)
# Out:
# str

# %%
#float to string
f = 5.10
k = str(f)
k
# Out:
# '5.1'

# %%
#float inti integer
y = int(f)
y
# Out:
# 5

# %%
#string into interger
i = '10'
z = int(i)
print(z)
type(z)
# Out:
# 10
# int

# %%
i ="key"
k = int(i)
k
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-f8b06512fdc0> in <module>
#       1 i ="key"
# ----> 2 k = int(i)
#       3 k
#
# ValueError: invalid literal for int() with base 10: 'key'

# %%
i = '10.5'
f = int(float(i))
f
# Out:
# 10

# %% [raw]
# Type casting conversions:
# 1. implicit
# 2. explicit

# %% [markdown]
# # 1. implicit

# %%
a = 10.45
b =4
c =a+b
print(c)
type(c)
# Out:
# 14.45
# float

# %% [markdown]
# # operators

# %%
a = 10.45
b =4
c =a-b
print(c)
# Out:
# 6.449999999999999

# %%
a = 15
b =2
c =a*b
print(c)
# Out:
# 30

# %%
a = 15
b =2
c =a//b # it will stay as int. -- double slash----divisor
print(c)
# Out:
# 7

# %%
a = 15
b =2
c =a/b # default it convrts to float when we use slash for division.---divisor
print(c)
# Out:
# 7.5

# %%
a = 10
b =2
c =a%b # looks for reminder
print(c)
# Out:
# 0

# %%
a = "srk\t" +"ravipati" # a = "srk"+' '+ "ravipati"
print(a)
# Out:
# srk	ravipati

# %%
a = 1+ "srk"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-b96d91506a39> in <module>
# ----> 1 a = 1+ "srk"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = "srk" -"ravipati"
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-d2ccf364a487> in <module>
# ----> 1 a = "srk" -"ravipati"
#       2 a
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a = "srk " *4
a
# Out:
# 'srk srk srk srk '

# %%
a = 10
b = 10*2
b
# Out:
# 20

# %%
a = 15
b =2

c = a**b
c
# Out:
# 225

# %%
a = int(input('enter value of a :')) # it takes string by default
b = int(input('enter value of b :'))
c = a+b
print(c)
# Out:
# enter value of a :10
# enter value of b :20
# 30

# %%
r = int(input('enter vaulue of r'))
pi = 3.14
area = pi*(r**2)
print(area)
# Out:
# enter vaulue of r10
# 314.0

# %%
height = int(input('enter the height :'))
weight = int(input('enter the weight :'))
BMI = weight/(height**2)
BMI
# Out:
# enter the height :169
# enter the weight :75
# 0.0026259584748433177

# %% [markdown]
# # Relational operators

# %%
x = 100
y = 12
x >=y
# Out:
# True

# %%
x <= y
# Out:
# False

# %%
x>y
# Out:
# True

# %%
x!=y
# Out:
# True

# %%
x ==y
# Out:
# False

# %%
b = 10
b +=2
b
# Out:
# 12

# %%
b= 10
b -=2
b
# Out:
# 8

# %%
b = 10
  b
# Out:
#   File "<ipython-input-116-9bfe9438ac0c>", line 2
#     b
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # print commands

# %%
a = 10
b = 20
print("a value is ",a ,"b value is ",b)
# Out:
# a value is  10 b value is  20

# %%
a = 10
b = 20
print("a value is {}; b value is {} ".format(a,b))
# Out:
# a value is 10; b value is 20

# %%
a = 10.25
b = 20.45
print("a value is %d ; b value is %d "%(a,b))
# Out:
# a value is 10 ; b value is 20

# %% [markdown]
# # length

# %%
a = "great learning"
len(a) #
# Out:
# 14

# %%
v = a.upper()
v
# Out:
# 'GREAT LEARNING'

# %%
c= v.lower()
c
# Out:
# 'great learning'

# %%
a.capitalize()
# Out:
# 'Great learning'

# %%
a.title()
# Out:
# 'Great Learning'

# %%
a.replace('g','G')
# Out:
# 'Great learninG'

# %%
a.replace(' ','')
# Out:
# 'greatlearning'

# %% [markdown]
# # Data slicing

# %%
a[2::]
# Out:
# 'eat learning'

# %%
a[2:7:]
# Out:
# 'eat l'

# %%
a[2:5:]
# Out:
# 'eat'

# %%
a[7::]
# Out:
# 'earning'

# %%
a[7:11:]
# Out:
# 'earn'

# %%
# reverse indexing
a = 'mom'
a_r = a[::-1]
a ==a_r
# Out:
# True
