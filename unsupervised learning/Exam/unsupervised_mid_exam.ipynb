# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# 1. Data Understanding (5 marks) a. Read the dataset (tab, csv, xls, txt, inbuilt dataset). What are the number of rows and no. of cols & types of variables (continuous, categorical etc.)? (1 MARK)

# %%
df =pd.read_csv('Q04_Wholesale+customers+data.csv')

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
df.shape
# Out:
# (440, 8)

# %% [markdown]
# no of rows = 440
# no of columns = 8

# %% [markdown]
# ## null valuecheck

# %%
df.isna().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %% [markdown]
# so, there are no null values

# %% [markdown]
# ## ouliers check

# %%
for i in df.select_dtypes(include=['int64','float64']):
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# There are ouliersfor few variables.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %% [markdown]
# from the data, we can see all the variables are discrete as there wont be any 1.5 product.

# %% [markdown]
# so, No.of discrete variables = 8

# %% [raw]
# b. Calculate five-point summary for numerical variables (1 MARK) c

# %%
df.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %% [markdown]
# c. Summarize observations for categorical variables – no. of categories, % observations in each category.  (1 MARK)

# %%
for i in df.select_dtypes(include='int64'):
    print('no of observations in each catagory of',i,' \n',df[i].value_counts())
    print('\n')
    print('percentage of  observations in each catagory of',i,' \n',round(df[i].value_counts(normalize=True),2)*100)
    print('---------------------')
    print('\n')
    print('\n')
# Out:
# no of observations in each catagory of Channel
#  1    298
# 2    142
# Name: Channel, dtype: int64
#
#
# percentage of  observations in each catagory of Channel
#  1    68.0
# 2    32.0
# Name: Channel, dtype: float64
# ---------------------
#
#
#
#
# no of observations in each catagory of Region
#  3    316
# 1     77
# 2     47
# Name: Region, dtype: int64
#
#
# percentage of  observations in each catagory of Region
#  3    72.0
# 1    18.0
# 2    11.0
# Name: Region, dtype: float64
# ---------------------
#
#
#
#
# no of observations in each catagory of Fresh
#  9670     2
# 3        2
# 8040     2
# 514      2
# 18044    2
#         ..
# 8885     1
# 694      1
# 7864     1
# 1725     1
# 4098     1
# Name: Fresh, Length: 433, dtype: int64
#
#
# percentage of  observations in each catagory of Fresh
#  9670     0.0
# 3        0.0
# 8040     0.0
# 514      0.0
# 18044    0.0
#         ...
# 8885     0.0
# 694      0.0
# 7864     0.0
# 1725     0.0
# 4098     0.0
# ...

# %% [markdown]
# d. Generate the covariance and correlation tables for the data (1 MARK)

# %%
df.cov()
# Out:
#                       Channel      Region         Fresh          Milk  \
# Channel              0.219072    0.022479 -1.001431e+03  1.591511e+03
# Region               0.022479    0.599498  5.413960e+02  1.845044e+02
# Fresh            -1001.431156  541.395998  1.599549e+08  9.381789e+06
# Milk              1591.510799  184.504437  9.381789e+06  5.446997e+07
# Grocery           2707.889812   56.625813 -1.424713e+06  5.108319e+07
# Frozen            -459.096397  -79.101833  2.123665e+07  4.442612e+06
# Detergents_Paper  1419.357559   -5.473509 -6.147826e+06  2.328834e+07
# Delicassen          73.932564   98.722008  8.727310e+06  8.457925e+06
#
#                        Grocery        Frozen  Detergents_Paper    Delicassen
# Channel           2.707890e+03 -4.590964e+02      1.419358e+03  7.393256e+01
# Region            5.662581e+01 -7.910183e+01     -5.473509e+00  9.872201e+01
# Fresh            -1.424713e+06  2.123665e+07     -6.147826e+06  8.727310e+06
# ...

# %%
df.corr()
# Out:
#                    Channel    Region     Fresh      Milk   Grocery    Frozen  \
# Channel           1.000000  0.062028 -0.169172  0.460720  0.608792 -0.202046
# Region            0.062028  1.000000  0.055287  0.032288  0.007696 -0.021044
# Fresh            -0.169172  0.055287  1.000000  0.100510 -0.011854  0.345881
# Milk              0.460720  0.032288  0.100510  1.000000  0.728335  0.123994
# Grocery           0.608792  0.007696 -0.011854  0.728335  1.000000 -0.040193
# Frozen           -0.202046 -0.021044  0.345881  0.123994 -0.040193  1.000000
# Detergents_Paper  0.636026 -0.001483 -0.101953  0.661816  0.924641 -0.131525
# Delicassen        0.056011  0.045212  0.244690  0.406368  0.205497  0.390947
#
#                   Detergents_Paper  Delicassen
# Channel                   0.636026    0.056011
# Region                   -0.001483    0.045212
# Fresh                    -0.101953    0.244690
# Milk                      0.661816    0.406368
# ...

# %% [markdown]
# e. Create Visualization plots to find the relationship amongst the variables. (1 MARK)

# %%
plt.figure(figsize=(15,10))

sns.heatmap(df.corr(),annot =True)

# %% [markdown]
# we can see the groceries , detergent paper and milk  are  correlated from heat map.

# %%
sns.pairplot(df)

# %% [markdown]
# 2. How will you decide when to apply PCA based on the correlation? (2 marks)  Apply PCA on the above dataset and determine the number of PCA components to be used so that 95% of the variance in data is explained by the same. (8 marks)

# %% [raw]
# when the no.of columns are more  or when there is multicollinearity , we can apply dimensionality reduction technique PCA.

# %% [markdown]
# when the variables are highly collinear with each other then we can go with PCA.

# %% [markdown]
# ## Apply PCA

# %%
x =df.copy()

# %% [markdown]
# #Normalize the data

# %%
from sklearn.preprocessing import StandardScaler
st =StandardScaler()
xscaled =st.fit_transform(x)

# %% [markdown]
# # covariance matrix

# %%
cov_matrix = np.cov(xscaled.T)
print('Covariance Matrix \n%s', cov_matrix)
plt.tight_layout()
# Out:
# Covariance Matrix
# %s [[ 1.0022779   0.06216891 -0.1695574   0.46176975  0.61017902 -0.2025062
#    0.63747517  0.05613902]
#  [ 0.06216891  1.0022779   0.05541286  0.03236105  0.00771331 -0.02109215
#   -0.00148606  0.0453151 ]
#  [-0.1695574   0.05541286  1.0022779   0.10073872 -0.01188088  0.34666934
#   -0.10218518  0.24524735]
#  [ 0.46176975  0.03236105  0.10073872  1.0022779   0.7299942   0.1242762
#    0.66332323  0.40729398]
#  [ 0.61017902  0.00771331 -0.01188088  0.7299942   1.0022779  -0.04028429
#    0.92674693  0.20596461]
#  [-0.2025062  -0.02109215  0.34666934  0.1242762  -0.04028429  1.0022779
#   -0.13182451  0.39183801]
#  [ 0.63747517 -0.00148606 -0.10218518  0.66332323  0.92674693 -0.13182451
#    1.0022779   0.06944914]
#  [ 0.05613902  0.0453151   0.24524735  0.40729398  0.20596461  0.39183801
#    0.06944914  1.0022779 ]]

# %%
dffpiar =pd.DataFrame(xscaled)
plt.figure(figsize=(20,8))
axes =pd.plotting.scatter_matrix(dffpiar)
plt.tight_layout()

# %% [markdown]
# # Step 3: Calculate the eigenvalues and eigenvectors

# %%
eig_val ,eigvect = np.linalg.eig(cov_matrix)

# %%
print('Eigen Vectors \n%s', eig_val)
print('\n Eigen Values \n%s', eigvect)
# Out:
# Eigen Vectors
# %s [3.10707136 1.79404441 1.0140786  0.06293318 0.28176643 0.74007428
#  0.46035462 0.55790035]
#
#  Eigen Values
# %s [[-4.28291564e-01 -2.04698855e-01 -8.29798863e-02  1.93353734e-02
#    1.39899044e-01  2.96441646e-02 -8.63506696e-01  3.62058452e-02]
#  [-2.47260253e-02  4.31296430e-02 -9.82500889e-01 -1.54504484e-03
#   -2.32799384e-02  7.78446249e-02  8.97647905e-02 -1.32508923e-01]
#  [ 2.53194580e-02  5.13444679e-01 -8.89509074e-02 -3.38511136e-02
#   -2.71736934e-02 -7.98475924e-01 -1.47474736e-01  2.58116864e-01]
#  [-4.74409947e-01  2.05540611e-01  2.57510842e-02 -3.92913471e-02
#    7.89020414e-01  5.40220237e-02  3.15932560e-01  7.20857633e-02]
#  [-5.36329145e-01 -8.71761988e-03  4.53143572e-02  7.15984124e-01
#   -3.53064294e-01 -1.21586244e-01  2.13698887e-01 -1.11729898e-01]
#  [ 2.99745579e-02  5.92745252e-01  1.22156522e-01 -1.29832249e-02
#   -5.33679297e-03  1.61316883e-01 -1.94359931e-01 -7.54212444e-01]
# ...

# %% [markdown]
# # variance

# %%
tot = sum(eig_val)
var_exp = [( i /tot ) * 100 for i in sorted(eig_val, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
print("Cumulative Variance Explained", cum_var_exp)
# Out:
# Cumulative Variance Explained [ 38.75012291  61.12471086  73.77188431  83.00178803  89.959693
#   95.70104744  99.21512312 100.        ]

# %%
plt.figure(figsize=(6 , 4))
plt.bar(range(8), var_exp, alpha = 0.5, align = 'center', label = 'Individual explained variance')
plt.step(range(8), cum_var_exp, where='mid', label = 'Cumulative explained variance')
plt.ylabel('Explained Variance Ratio')
plt.xlabel('Principal Components')
plt.legend(loc = 'best')
plt.tight_layout()
plt.show()

# %% [markdown]
# For getting 95% of explained variance we need to take 6 PC's

# %%
from sklearn.decomposition import PCA

pca =PCA(n_components=6)

# %%
xpca = pca.fit_transform(xscaled)

# %% [raw]
# 3. Use PCA dimensions to cluster the data. Apply K-means/ Agglomerative clustering based on the data. (15 Marks) Some pointers which would help you, but don’t be limited by these a. Find the optimal K Value. (3 marks)

# %% [markdown]
# ## Applying Kmeans

# %%
from sklearn.cluster import KMeans
kmeans = KMeans()
kmeans.fit(xpca)
kmeans.cluster_centers_
kmeans.inertia_
# Out:
# 903.6950053073032

# %%
cluster_range = range( 1, 15 )
cluster_errors = []
for num_clusters in cluster_range:
  clusters = KMeans( num_clusters )#, n_init = 10
  clusters.fit(xpca)
  labels = clusters.labels_
  centroids = clusters.cluster_centers_
  cluster_errors.append( clusters.inertia_ )
clusters_df = pd.DataFrame( { "num_clusters":cluster_range, "cluster_errors": cluster_errors } )
clusters_df#[0:15]
# Out:
#     num_clusters  cluster_errors
# 0              1     3368.676870
# 1              2     2448.355126
# 2              3     1999.560739
# 3              4     1702.255592
# 4              5     1417.140996
# 5              6     1167.324676
# 6              7     1045.901147
# 7              8      904.375508
# 8              9      838.081320
# 9             10      763.551999
# 10            11      694.729017
# 11            12      654.868777
# 12            13      623.341669
# 13            14      573.336778

# %%
clusters_df.sort_values(by ='cluster_errors')
# Out:
#     num_clusters  cluster_errors
# 13            14      573.336778
# 12            13      623.341669
# 11            12      654.868777
# 10            11      694.729017
# 9             10      763.551999
# 8              9      838.081320
# 7              8      904.375508
# 6              7     1045.901147
# 5              6     1167.324676
# 4              5     1417.140996
# 3              4     1702.255592
# 2              3     1999.560739
# 1              2     2448.355126
# 0              1     3368.676870

# %%
# Elbow plot

plt.figure(figsize=(12,6))
plt.plot( clusters_df.num_clusters, clusters_df.cluster_errors, marker = "o" )

# %% [markdown]
# so from the elbow curve , we can see that there can be 8 clusters, but from the scatter plot we can observe 3 diff clusters.

# %%
kmeansa = KMeans(n_clusters= 8)
kmeansa.fit(xpca)
print('inertia',kmeansa.inertia_)
print('centroids',kmeansa.cluster_centers_)
dflabel =pd.DataFrame(kmeansa.labels_)
# Out:
# inertia 903.7573694604207
# centroids [[-0.97305485 -0.13007008 -0.56285467  0.21879919  0.10416421  0.40161652]
#  [-0.6574392   1.92371543 -0.39476173 -1.34970171 -0.26194686 -0.1214973 ]
#  [ 1.151518   -0.65539671 -0.48676041  0.12557692 -0.08089334 -0.87738467]
#  [ 3.21443568 -0.52050907  0.57378596  0.12325034  0.03580298 -0.02877907]
#  [-0.91260254 -0.09580582  1.57656859 -0.01697425 -0.14554794  0.08470428]
#  [-0.42318379  6.69963592  1.16292955  1.43818856  6.15928577 -1.29086524]
#  [ 9.10166187  0.753606    0.10355909 -1.84816575  0.68259918  2.5472933 ]
#  [ 5.03618824 15.17265913  0.29488209  8.63323403 -4.50498942 -0.07920543]]

# %%
dflabel.rename(columns={0:'labels1'},inplace =True)

# %%
dflabel
# Out:
#      labels1
# 0          2
# 1          2
# 2          2
# 3          0
# 4          2
# ..       ...
# 435        1
# 436        1
# 437        3
# 438        0
# 439        0
#
# [440 rows x 1 columns]

# %%
df =df.join(dflabel)

# %%
df.isna().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# labels1             0
# dtype: int64

# %%
df.shape
# Out:
# (440, 9)

# %%
sns.pairplot(df,diag_kind='hist',hue ='labels1')

# %%
sns.scatterplot(df.Grocery,df.Detergents_Paper,hue =df.labels1)

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669  9656     7561     214              2674
# 1        2       3   7057  9810     9568    1762              3293
# 2        2       3   6353  8808     7684    2405              3516
# 3        1       3  13265  1196     4221    6404               507
# 4        2       3  22615  5410     7198    3915              1777
#
#    Delicassen  labels1
# 0        1338        2
# 1        1776        2
# 2        7844        2
# 3        1788        0
# 4        5185        2

# %%
x = df.drop(columns='labels1')
y = df.labels1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(xpca, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr =LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
df.labels1.value_counts()
# Out:
# 0    175
# 2     93
# 4     86
# 1     41
# 3     37
# 6      5
# 5      2
# 7      1
# Name: labels1, dtype: int64

# %% [markdown]
# As they are multiclass with imbalanced data , we use the metrics of f1 score.

# %%
from sklearn.metrics import f1_score

y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)
print('f1score of train',f1_score(y_train,y_train_pred,average='weighted'))
print('f1score of test',f1_score(y_test,y_test_pred,average='weighted'))
# Out:
# f1score of train 0.9862706172352547
# f1score of test 0.9656280268437802

# %%
def evaluation_train_test(model,X_train,y_train,X_test,y_test):
    y_train_prob = model.predict_proba(X_train)[:,1]
    y_train_pred = model.predict(X_train)
    y_test_prob = model.predict_proba(X_test)[:,1]
    y_test_pred = model.predict(X_test)
    from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score,roc_curve,classification_report
    print('Train accuracy score for train of',model,':',accuracy_score(y_train,y_train_pred))
    print('Test accuracy score for test of ',model,':',accuracy_score(y_test,y_test_pred))
    
   
    print('Train classification report \n',classification_report(y_train,y_train_pred))
    print('Test classification report \n',classification_report(y_test,y_test_pred))

    
    fig,axes =plt.subplots(1,2,figsize =(15,5))
    sns.heatmap(confusion_matrix(y_train,y_train_pred),annot =True,fmt ='g',ax =axes[0])
    #plt.show()
    sns.heatmap(confusion_matrix(y_test,y_test_pred),annot =True,fmt ='g',ax =axes[1])
    plt.show()

# %%
evaluation_train_test(lr,X_train,y_train,X_test,y_test)

# %% [markdown]
# ## agglomerative clustering

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
z = linkage(xpca, method='single')#
dendrogram(z,truncate_mode='lastp',p =12)
plt.title('Dendrogram')
plt.xlabel('Data Points')
plt.ylabel('Euclidean Distances')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
agg =AgglomerativeClustering()

# %%
agg.fit(xpca)

# %%
dflab =pd.DataFrame(agg.labels_)

# %%
df =df.join(dflab)

# %%
df.rename(columns={0:'agglabels'},inplace =True)

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669  9656     7561     214              2674
# 1        2       3   7057  9810     9568    1762              3293
# 2        2       3   6353  8808     7684    2405              3516
# 3        1       3  13265  1196     4221    6404               507
# 4        2       3  22615  5410     7198    3915              1777
#
#    Delicassen  labels1  agglabels
# 0        1338        2          0
# 1        1776        2          0
# 2        7844        2          0
# 3        1788        0          1
# 4        5185        2          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
#  8   labels1           440 non-null    int32
#  9   agglabels         440 non-null    int64
# dtypes: int32(1), int64(9)
# memory usage: 32.8 KB

# %%
sns.pairplot(df,diag_kind='hist', hue = 'agglabels')

# %%
x = df.drop(columns=['labels1','agglabels'])
y = df.agglabels

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(xpca, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr1 =LogisticRegression()
lr1.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import f1_score

y_train_pred = lr1.predict(X_train)
y_test_pred = lr1.predict(X_test)
print('f1score of train',f1_score(y_train,y_train_pred))
print('f1score of test',f1_score(y_test,y_test_pred))
# Out:
# f1score of train 0.9974160206718347
# f1score of test 0.9951690821256038

# %%
evaluation_train_test(lr,X_train,y_train,X_test,y_test)
# Out:
# Train accuracy score for train of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False) : 0.9965986394557823
# Test accuracy score for test of  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False) : 0.9931506849315068
# Train classification report
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       100
#            1       1.00      0.99      1.00       194
#
# ...

# %%
so, our model gives the best prediction with 0.99 in both train and test.

# %% [raw]
# d. Write down a business interpretation/explanation of the model – which variables are affecting the target the most and explain the relationship. What changes from the base model had the most effect on model performance? (2 marks)

# %%
we can intrepret our bussiness as it has divided into 2 clusters using Agglomerative
so, our data has two groups in which the products belongs to cetain catagory depending on the bussiness.

# %%
dd =pd.DataFrame(lr1.coef_,columns=['PC1','PC2','PC3','PC4','PC5','PC6'])
dd =dd.T
dd.sort_values(by =0,ascending =False)
# Out:
#             0
# PC6  2.986065
# PC2  0.601840
# PC3  0.220674
# PC4 -0.399485
# PC5 -0.402067
# PC1 -1.947537

# %%
 these are the coeffients of 6 PC's. so, our model took model importance of 6th Pc and 2nd Pc.
