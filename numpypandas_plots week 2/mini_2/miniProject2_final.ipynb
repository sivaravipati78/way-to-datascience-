# %%
import pandas as pd
import numpy as np

# %%
df1 =pd.read_csv(r'C:\Users\SRK\Desktop\siva_python\w2\fifa.csv')
df2 =pd.read_csv(r'C:\Users\SRK\Desktop\siva_python\w2\fifa_+variable_information.csv')

# %%
df1.Value.replace(to_replace=r'\A€',value ='', regex=True,inplace=True)

# %%
#df1.Value.mean()

# %%
df1.Value
# Out:
# 0        €110.5M
# 1           €77M
# 2        €118.5M
# 3           €72M
# 4          €102M
# 5           €93M
# 6           €67M
# 7           €80M
# 8           €51M
# 9           €68M
# 10          €77M
# 11        €76.5M
# 12          €44M
# 13          €60M
# 14          €63M
# 15          €89M
# 16        €83.5M
# 17          €78M
# 18          €58M
# 19        €53.5M
# 20        €51.5M
# 21          €60M
# 22          €38M
# 23        €64.5M
# 24          €27M
# 25          €81M
# 26        €69.5M
# 27        €59.5M
# 28        €69.5M
# 29          €62M
#           ...
# 18177       €70K
# 18178       €50K
# 18179       €50K
# 18180       €40K
# 18181       €50K
# 18182       €50K
# 18183         €0
# 18184       €40K
# 18185       €50K
# 18186       €60K
# 18187       €40K
# 18188       €60K
# 18189       €60K
# 18190       €60K
# 18191       €50K
# 18192       €50K
# 18193       €50K
# 18194       €50K
# 18195       €60K
# 18196       €60K
# 18197       €60K
# ...

# %%
df1.Value.replace(r'[KM]+$', '', regex=True).astype(float)
# Out:
# 0        110.5
# 1         77.0
# 2        118.5
# 3         72.0
# 4        102.0
# 5         93.0
# 6         67.0
# 7         80.0
# 8         51.0
# 9         68.0
# 10        77.0
# 11        76.5
# 12        44.0
# 13        60.0
# 14        63.0
# 15        89.0
# 16        83.5
# 17        78.0
# 18        58.0
# 19        53.5
# 20        51.5
# 21        60.0
# 22        38.0
# 23        64.5
# 24        27.0
# 25        81.0
# 26        69.5
# 27        59.5
# 28        69.5
# 29        62.0
#          ...
# 18177     70.0
# 18178     50.0
# 18179     50.0
# 18180     40.0
# 18181     50.0
# 18182     50.0
# 18183      0.0
# 18184     40.0
# 18185     50.0
# 18186     60.0
# 18187     40.0
# 18188     60.0
# 18189     60.0
# 18190     60.0
# 18191     50.0
# 18192     50.0
# 18193     50.0
# 18194     50.0
# 18195     60.0
# 18196     60.0
# 18197     60.0
# 18198     60.0
# 18199     70.0
# 18200     60.0
# 18201     60.0
# 18202     60.0
# 18203     60.0
# ...

# %%
df1.Value.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(2410695.8861976163).replace(['K','M'], [10**3, 10**6]).astype(int)
# Out:
# 0        1000000
# 1        1000000
# 2        1000000
# 3        1000000
# 4        1000000
# 5        1000000
# 6        1000000
# 7        1000000
# 8        1000000
# 9        1000000
# 10       1000000
# 11       1000000
# 12       1000000
# 13       1000000
# 14       1000000
# 15       1000000
# 16       1000000
# 17       1000000
# 18       1000000
# 19       1000000
# 20       1000000
# 21       1000000
# 22       1000000
# 23       1000000
# 24       1000000
# 25       1000000
# 26       1000000
# 27       1000000
# 28       1000000
# 29       1000000
#           ...
# 18177       1000
# 18178       1000
# 18179       1000
# 18180       1000
# 18181       1000
# 18182       1000
# 18183    2410695
# 18184       1000
# 18185       1000
# 18186       1000
# 18187       1000
# 18188       1000
# 18189       1000
# 18190       1000
# 18191       1000
# 18192       1000
# 18193       1000
# 18194       1000
# 18195       1000
# 18196       1000
# 18197       1000
# ...

# %%
df1.Value = (df1.Value.replace(r'[KM]+$', '', regex=True).astype(float) * \
df1.Value.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(2410695.8861976163).replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
df1.Value
# Out:
# 0        110500000.0
# 1         77000000.0
# 2        118500000.0
# 3         72000000.0
# 4        102000000.0
# 5         93000000.0
# 6         67000000.0
# 7         80000000.0
# 8         51000000.0
# 9         68000000.0
# 10        77000000.0
# 11        76500000.0
# 12        44000000.0
# 13        60000000.0
# 14        63000000.0
# 15        89000000.0
# 16        83500000.0
# 17        78000000.0
# 18        58000000.0
# 19        53500000.0
# 20        51500000.0
# 21        60000000.0
# 22        38000000.0
# 23        64500000.0
# 24        27000000.0
# 25        81000000.0
# 26        69500000.0
# 27        59500000.0
# 28        69500000.0
# 29        62000000.0
#             ...
# 18177        70000.0
# 18178        50000.0
# 18179        50000.0
# 18180        40000.0
# 18181        50000.0
# 18182        50000.0
# 18183            0.0
# 18184        40000.0
# 18185        50000.0
# 18186        60000.0
# 18187        40000.0
# 18188        60000.0
# ...

# %%
#df1.Value = (df1.Value.replace(r'[KM]+$', '', regex=True).astype(float) * \
#df1.Value.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(df1.Value.mean()).replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
df1.Wage.replace(to_replace=r'\A€',value ='', regex=True,inplace=True)
df1.Wage = (df1.Wage.replace(r'[KM]+$', '', regex=True).astype(float) * \
df1.Wage.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1).replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
df1['Joined'] =df1.Joined.str.split(',').str[1].astype(float)

df1.Joined.fillna(df1.Joined.mean(),inplace =True)

#astype(int)

# %%
df1.Joined = df1.Joined.astype(int)

# %%
df1.Joined
# Out:
# 0        2004
# 1        2018
# 2        2017
# 3        2011
# 4        2015
# 5        2012
# 6        2012
# 7        2014
# 8        2005
# 9        2014
# 10       2014
# 11       2014
# 12       2010
# 13       2010
# 14       2016
# 15       2015
# 16       2010
# 17       2014
# 18       2014
# 19       2018
# 20       2008
# 21       2013
# 22       2011
# 23       2011
# 24       2005
# 25       2018
# 26       2017
# 27       2013
# 28       2016
# 29       2010
#          ...
# 18177    2016
# 18178    2018
# 18179    2018
# 18180    2013
# 18181    2017
# 18182    2018
# 18183    2018
# 18184    2017
# 18185    2018
# 18186    2016
# 18187    2017
# 18188    2017
# 18189    2017
# 18190    2018
# 18191    2018
# 18192    2018
# 18193    2018
# 18194    2018
# 18195    2018
# 18196    2017
# 18197    2018
# 18198    2018
# 18199    2018
# 18200    2015
# 18201    2018
# 18202    2017
# 18203    2018
# 18204    2017
# 18205    2018
# 18206    2018
# ...

# %%
#df1.Joined.replace(to_replace=r'\s,',value ='', regex=True,inplace=True)
#df1.Joined
#df1.Joined.str.split(',')

# %%
df1['Contract Valid Until']
# Out:
# 0                2021
# 1                2022
# 2                2022
# 3                2020
# 4                2023
# 5                2020
# 6                2020
# 7                2021
# 8                2020
# 9                2021
# 10               2021
# 11               2022
# 12               2019
# 13               2020
# 14               2023
# 15               2022
# 16               2024
# 17               2023
# 18               2022
# 19               2024
# 20               2023
# 21               2020
# 22               2021
# 23               2021
# 24               2020
# 25               2022
# 26               2023
# 27               2021
# 28       Jun 30, 2019
# 29               2022
#              ...
# 18177            2019
# 18178            2018
# 18179            2020
# 18180            2019
# 18181            2018
# 18182            2021
# 18183            2023
# 18184            2021
# 18185            2018
# 18186            2019
# ...

# %%
#df1.Contract Valid Until.replace(to_replace=r'\s,',value ='', regex=True,inplace=True)
#df1.Contract Valid Until
#df1.Contract Valid Until.str.split(',')

# %%
#df1[df1['Contract Valid Until'].isnull()]['Contract Valid Until']
#df1['Contract Valid Until'].fillna(2030)
#df1['Contract Valid Until'].replace(np.nan,2033)
#fillna(2030)
#df1['Contract Valid Until'].

#[452]
df1['Contract Valid Until'][452]
df1['Contract Valid Until'][450]
# Out:
# '2021'

# %%
#df1['Contract Valid Until'].replace('NaT',np.mean,inplace = True)
#df1[df1['Contract Valid Until'].isnull()]['Contract Valid Until']

# %%
df1['Contract Valid Until'].fillna(method ='pad',inplace =True)

# %%
df1[df1['Contract Valid Until'].isnull()]['Contract Valid Until']
# Out:
# Series([], Name: Contract Valid Until, dtype: object)

# %%
#df1 = df1.set_index('Contract Valid Until').resample('S').ffill().reset_index()
#df1[df1['Contract Valid Until'].isnull()]['Contract Valid Until']

# %%
df1['Contract Valid Until'] = pd.to_datetime(df1['Contract Valid Until'])

# %%
#df1['Contract Valid Until'] = pd.to_datetime(df1['Contract Valid Until'])
#.fillna(df1['Contract Valid Until'].mean(),inplace =True)
#df1['Contract Valid Until']
#df1[df1['Contract Valid Until'].isnull()]['Contract Valid Until']

# %%
#df1['Contract Valid Until'] =df1['Contract Valid Until'].str.split(',').str[1].astype(float)

#df1['Contract Valid Until'].fillna(df1['Contract Valid Until'].mean(),inplace =True)

#astype(int)
#df1['Contract Valid Until']
#.astype(int)

# %%
#df1[df1['Contract Valid Until'].isnull()]

# %%
df1.Height.replace(to_replace = "'",value ='.',regex=True,inplace=True)
#.astype(float)
#df1.Height.astype(float)
#.astype(float)
#df1.Height.astype(float)
#df1.Height.astype(float)
df1.Height
#df1.Height.astype(float)
#to_replace=r'\s,',value =''
# Out:
# 0         5.7
# 1         6.2
# 2         5.9
# 3         6.4
# 4        5.11
# 5         5.8
# 6         5.8
# 7         6.0
# 8         6.0
# 9         6.2
# 10        6.0
# 11        6.0
# 12        6.2
# 13        5.8
# 14        5.6
# 15       5.10
# 16        6.2
# 17        5.9
# 18        6.2
# 19        6.6
# 20        6.2
# 21        6.1
# 22        6.4
# 23        5.8
# 24        6.2
# 25       5.10
# 26        5.9
# 27        6.1
# 28       5.11
# 29        5.4
#          ...
# 18177    5.10
# 18178     6.0
# 18179     6.2
# 18180     6.1
# 18181    5.11
# 18182    5.10
# 18183     6.2
# 18184     6.1
# 18185    5.11
# 18186    5.10
# 18187    5.10
# 18188    5.10
# 18189    5.10
# 18190     5.9
# 18191    5.11
# 18192     6.1
# 18193     5.8
# 18194     6.3
# 18195     5.8
# 18196     5.7
# 18197    5.10
# 18198    5.11
# 18199     5.6
# 18200     5.9
# 18201     6.1
# 18202     5.9
# 18203     6.3
# 18204     5.8
# 18205    5.10
# 18206    5.10
# ...

# %%
#df1.Height.fillna(df1.Height.mean)
df1.Height =df1.Height.astype(float)

# %%
df1.Height
# Out:
# 0        5.70
# 1        6.20
# 2        5.90
# 3        6.40
# 4        5.11
# 5        5.80
# 6        5.80
# 7        6.00
# 8        6.00
# 9        6.20
# 10       6.00
# 11       6.00
# 12       6.20
# 13       5.80
# 14       5.60
# 15       5.10
# 16       6.20
# 17       5.90
# 18       6.20
# 19       6.60
# 20       6.20
# 21       6.10
# 22       6.40
# 23       5.80
# 24       6.20
# 25       5.10
# 26       5.90
# 27       6.10
# 28       5.11
# 29       5.40
#          ...
# 18177    5.10
# 18178    6.00
# 18179    6.20
# 18180    6.10
# 18181    5.11
# 18182    5.10
# 18183    6.20
# 18184    6.10
# 18185    5.11
# 18186    5.10
# 18187    5.10
# 18188    5.10
# 18189    5.10
# 18190    5.90
# 18191    5.11
# 18192    6.10
# 18193    5.80
# 18194    6.30
# 18195    5.80
# 18196    5.70
# 18197    5.10
# 18198    5.11
# 18199    5.60
# 18200    5.90
# 18201    6.10
# 18202    5.90
# 18203    6.30
# 18204    5.80
# 18205    5.10
# 18206    5.10
# ...

# %%
df1.Height.fillna(method = 'pad',inplace = True)

# %%
df1.Height
# Out:
# 0        5.70
# 1        6.20
# 2        5.90
# 3        6.40
# 4        5.11
# 5        5.80
# 6        5.80
# 7        6.00
# 8        6.00
# 9        6.20
# 10       6.00
# 11       6.00
# 12       6.20
# 13       5.80
# 14       5.60
# 15       5.10
# 16       6.20
# 17       5.90
# 18       6.20
# 19       6.60
# 20       6.20
# 21       6.10
# 22       6.40
# 23       5.80
# 24       6.20
# 25       5.10
# 26       5.90
# 27       6.10
# 28       5.11
# 29       5.40
#          ...
# 18177    5.10
# 18178    6.00
# 18179    6.20
# 18180    6.10
# 18181    5.11
# 18182    5.10
# 18183    6.20
# 18184    6.10
# 18185    5.11
# 18186    5.10
# 18187    5.10
# 18188    5.10
# 18189    5.10
# 18190    5.90
# 18191    5.11
# 18192    6.10
# 18193    5.80
# 18194    6.30
# 18195    5.80
# 18196    5.70
# 18197    5.10
# 18198    5.11
# 18199    5.60
# 18200    5.90
# 18201    6.10
# 18202    5.90
# 18203    6.30
# 18204    5.80
# 18205    5.10
# 18206    5.10
# ...

# %%
df1.Height.astype(float)
# Out:
# 0        5.70
# 1        6.20
# 2        5.90
# 3        6.40
# 4        5.11
# 5        5.80
# 6        5.80
# 7        6.00
# 8        6.00
# 9        6.20
# 10       6.00
# 11       6.00
# 12       6.20
# 13       5.80
# 14       5.60
# 15       5.10
# 16       6.20
# 17       5.90
# 18       6.20
# 19       6.60
# 20       6.20
# 21       6.10
# 22       6.40
# 23       5.80
# 24       6.20
# 25       5.10
# 26       5.90
# 27       6.10
# 28       5.11
# 29       5.40
#          ...
# 18177    5.10
# 18178    6.00
# 18179    6.20
# 18180    6.10
# 18181    5.11
# 18182    5.10
# 18183    6.20
# 18184    6.10
# 18185    5.11
# 18186    5.10
# 18187    5.10
# 18188    5.10
# 18189    5.10
# 18190    5.90
# 18191    5.11
# 18192    6.10
# 18193    5.80
# 18194    6.30
# 18195    5.80
# 18196    5.70
# 18197    5.10
# 18198    5.11
# 18199    5.60
# 18200    5.90
# 18201    6.10
# 18202    5.90
# 18203    6.30
# 18204    5.80
# 18205    5.10
# 18206    5.10
# ...

# %%
#df1.Height[df1.Height.isnull()]

# %%
df1.Weight.replace(to_replace=r'lbs$',value ='', regex=True,inplace=True)

# %%
df1.Weight = df1.Weight.astype(float,inplace =True)

#method ='pad',inplace = True

# %%
df1.Weight.fillna(df1.Weight.mean(),inplace = True)

# %%
df1.Weight[df1.Weight.isnull()]
# Out:
# Series([], Name: Weight, dtype: float64)

# %%
df1.Weight
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
# 5        163.0
# 6        146.0
# 7        190.0
# 8        181.0
# 9        192.0
# 10       176.0
# 11       168.0
# 12       172.0
# 13       148.0
# 14       159.0
# 15       165.0
# 16       196.0
# 17       161.0
# 18       187.0
# 19       212.0
# 20       168.0
# 21       170.0
# 22       203.0
# 23       154.0
# 24       187.0
# 25       161.0
# 26       157.0
# 27       185.0
# 28       172.0
# 29       130.0
#          ...
# 18177    163.0
# 18178    176.0
# 18179    163.0
# 18180    172.0
# 18181    134.0
# 18182    165.0
# 18183    190.0
# 18184    179.0
# 18185    159.0
# 18186    174.0
# 18187    161.0
# 18188    148.0
# 18189    165.0
# 18190    176.0
# 18191    168.0
# 18192    165.0
# 18193    146.0
# 18194    187.0
# 18195    141.0
# 18196    146.0
# 18197    141.0
# 18198    154.0
# 18199    150.0
# 18200    157.0
# 18201    168.0
# 18202    134.0
# 18203    170.0
# ...

# %%
df1['Release Clause']
# Out:
# 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
# 5        €172.1M
# 6        €137.4M
# 7          €164M
# 8        €104.6M
# 9        €144.5M
# 10       €127.1M
# 11       €156.8M
# 12        €90.2M
# 13         €111M
# 14       €121.3M
# 15       €153.5M
# 16       €160.7M
# 17       €165.8M
# 18       €123.3M
# 19       €113.7M
# 20       €105.6M
# 21         €111M
# 22        €62.7M
# 23       €119.3M
# 24        €44.6M
# 25       €166.1M
# 26       €137.3M
# 27       €126.4M
# 28           NaN
# 29       €105.4M
#           ...
# 18177      €193K
# 18178       €94K
# 18179      €119K
# 18180       €78K
# 18181      €109K
# 18182      €101K
# 18183        NaN
# 18184       €78K
# 18185       €88K
# 18186      €167K
# 18187       €66K
# 18188      €143K
# 18189      €125K
# 18190      €165K
# 18191      €119K
# 18192      €119K
# 18193       €99K
# 18194      €109K
# 18195      €153K
# 18196      €113K
# 18197       €88K
# ...

# %%
df1['Release Clause'].replace(to_replace=r'\A€',value ='', regex=True,inplace=True)
df1['Release Clause'] = (df1['Release Clause'].replace(r'[KM]+$', '', regex=True).astype(float) * \
df1['Release Clause'].str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1).replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
df1['Release Clause']
# Out:
# 0        226500000.0
# 1        127100000.0
# 2        228100000.0
# 3        138600000.0
# 4        196400000.0
# 5        172100000.0
# 6        137400000.0
# 7        164000000.0
# 8        104600000.0
# 9        144500000.0
# 10       127100000.0
# 11       156800000.0
# 12        90200000.0
# 13       111000000.0
# 14       121300000.0
# 15       153500000.0
# 16       160700000.0
# 17       165800000.0
# 18       123300000.0
# 19       113700000.0
# 20       105600000.0
# 21       111000000.0
# 22        62700000.0
# 23       119300000.0
# 24        44600000.0
# 25       166100000.0
# 26       137300000.0
# 27       126400000.0
# 28               NaN
# 29       105400000.0
#             ...
# 18177       193000.0
# 18178        94000.0
# 18179       119000.0
# 18180        78000.0
# 18181       109000.0
# 18182       101000.0
# 18183            NaN
# 18184        78000.0
# 18185        88000.0
# 18186       167000.0
# 18187        66000.0
# 18188       143000.0
# ...

# %%
df1.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
pd.set_option("display.width",1000)
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
df1.head()
# Out:
#        ID               Name  Age                                           Photo Nationality                                 Flag  Overall  Potential                 Club                                     Club Logo        Value      Wage Preferred Foot  International Reputation  Weak Foot  Skill Moves       Work Rate   Body Type Position  Jersey Number  Joined Loaned From Contract Valid Until  Height  Weight  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  Release Clause
# ...

# %%
'Value'
'Wage'
'Joined'
'Contract Valid Until'
'Height'
'Weight'
'Release Clause'
# Out:
# 'Release Clause'

# %%
df1.Name[df1.Name.duplicated()]
# Out:
# 516               Marcelo
# 540              M. Gómez
# 683               Mariano
# 835              Fernando
# 901              L. López
# 935                 Bruno
# 948           J. Martínez
# 1117               Danilo
# 1132            L. Acosta
# 1155             Paulinho
# 1187               Otávio
# 1189        R. Funes Mori
# 1236              Marcelo
# 1249              M. Díaz
# 1337            S. García
# 1350          J. Cuadrado
# 1403           M. Dembélé
# 1435              Rafinha
# 1571               Felipe
# 1628               Danilo
# 1629         J. Hernández
# 1653            I. Traoré
# 1668               Rafael
# 1713                Naldo
# 1742            Guilherme
# 1760            R. Thomas
# 1817             Paulinho
# 1838               Sandro
# 1901          Fernandinho
# 1951         G. Rodríguez
# 2029         J. Hernández
# 2062            J. Corona
# 2064            S. Romero
# 2084         J. Rodríguez
# 2130             A. Touré
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null float64
# Wage                        18207 non-null float64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# Work Rate                   18159 non-null object
# ...

# %%
#nd =df1.Name.unique()

# %%
#df.name = df1.Name.unique()
#df1.Overall[df1.Name ==nd]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(df1.Overall,kde =True,rug=True,hist =True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
#sns.pairplot(df)
cols =['Overall','Value','Wage','International Reputation','Height','Weight','Release Clause']
sns.pairplot(df1[cols],height =2.5)
plt.show()
#Overall, Value, Wage, International Reputation, Height, Weight, Release Clause
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\SRK\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df1['Contract Valid Until']=pd.to_datetime(df1['Contract Valid Until'])
date=df1['Contract Valid Until'].dt.year
df1['Contract Valid Until']=date
df1.head(5)
# Out:
#        ID               Name  Age                                           Photo Nationality                                 Flag  Overall  Potential                 Club                                     Club Logo        Value      Wage Preferred Foot  International Reputation  Weak Foot  Skill Moves       Work Rate   Body Type Position  Jersey Number  Joined Loaned From  Contract Valid Until  Height  Weight  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  Release Clause
# ...

# %%
df2=df1[['Name','Age','Overall','Value','Wage','Contract Valid Until','Position']]
df2.head(5)
# Out:
#                 Name  Age  Overall        Value      Wage  Contract Valid Until Position
# 0           L. Messi   31       94  110500000.0  565000.0                  2021       RF
# 1  Cristiano Ronaldo   33       94   77000000.0  405000.0                  2022       ST
# 2          Neymar Jr   26       92  118500000.0  290000.0                  2022       LW
# 3             De Gea   27       91   72000000.0  260000.0                  2020       GK
# 4       K. De Bruyne   27       91  102000000.0  355000.0                  2023      RCM

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null float64
# Wage                        18207 non-null float64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# Work Rate                   18159 non-null object
# ...

# %%
y=df2['Contract Valid Until'].mean()
df2['Contract Valid Until']=df2['Contract Valid Until'].fillna(int(y))
df2.head()
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                 Name  Age  Overall        Value      Wage  Contract Valid Until Position
# 0           L. Messi   31       94  110500000.0  565000.0                  2021       RF
# 1  Cristiano Ronaldo   33       94   77000000.0  405000.0                  2022       ST
# 2          Neymar Jr   26       92  118500000.0  290000.0                  2022       LW
# 3             De Gea   27       91   72000000.0  260000.0                  2020       GK
# 4       K. De Bruyne   27       91  102000000.0  355000.0                  2023      RCM

# %%
df2=df2[df2['Contract Valid Until']<=2020.0]

# %%
df2.sort_values(by='Overall',ascending=False).head(20)
# Out:
#                Name  Age  Overall       Value      Wage  Contract Valid Until Position
# 3            De Gea   27       91  72000000.0  260000.0                  2020       GK
# 6         L. Modrić   32       91  67000000.0  420000.0                  2020      RCM
# 8      Sergio Ramos   32       91  51000000.0  380000.0                  2020      RCB
# 5         E. Hazard   27       91  93000000.0  340000.0                  2020       LF
# 12         D. Godín   32       90  44000000.0  125000.0                  2019       CB
# 13      David Silva   32       90  60000000.0  285000.0                  2020      LCM
# 21        E. Cavani   31       89  60000000.0  200000.0                  2020       LS
# 24     G. Chiellini   33       89  27000000.0  215000.0                  2020      LCB
# 28     J. Rodríguez   26       88  69500000.0  315000.0                  2019      LAM
# 31       C. Eriksen   26       88  73500000.0  205000.0                  2020      CAM
# ...

# %%
sns.regplot(x='Overall',y='Value',data=df2)
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df3=df1[['Name','Age','Overall','Wage','Position']]

# %%
df4=df3.groupby('Position').apply(lambda x: x.sort_values(['Overall'],ascending=False).head(5))

# %%
df4
# Out:
#                               Name  Age  Overall      Wage Position
# Position
# CAM      17           A. Griezmann   27       89  145000.0      CAM
#          31             C. Eriksen   26       88  205000.0      CAM
#          61        Roberto Firmino   26       86  195000.0      CAM
#          66              T. Müller   28       86  135000.0      CAM
#          74                M. Özil   29       86  190000.0      CAM
# CB       12               D. Godín   32       90  125000.0       CB
#          42              S. Umtiti   24       87  205000.0       CB
#          73             M. Benatia   31       86  160000.0       CB
#          89            N. Otamendi   30       85  170000.0       CB
#          102                 Naldo   35       85   38000.0       CB
# CDM      20        Sergio Busquets   29       89  315000.0      CDM
#          27               Casemiro   26       88  285000.0      CDM
#          72              M. Pjanić   28       86  180000.0      CDM
# ...

# %%
df5=df4.T
df5
# Out:
# Position           CAM                                                         CB                                                         CDM                                                       CF                                                 CM                                                            GK                                                           LAM                                                                   LB                                                           LCB                                                             LCM                                                             LDM                                                        LF                                                            LM                                                 LS                                                           LW                                               LWB                                                RAM                             \
# ...

# %%
df5=df5.drop('Position')
df5
# Out:
# Position           CAM                                                         CB                                                         CDM                                                       CF                                                 CM                                                            GK                                                           LAM                                                                   LB                                                           LCB                                                             LCM                                                             LDM                                                        LF                                                            LM                                                 LS                                                           LW                                               LWB                                                RAM                             \
# ...

# %%
df5=df5.T
df5
# Out:
#                               Name Age Overall    Wage
# Position
# CAM      17           A. Griezmann  27      89  145000
#          31             C. Eriksen  26      88  205000
#          61        Roberto Firmino  26      86  195000
#          66              T. Müller  28      86  135000
#          74                M. Özil  29      86  190000
# CB       12               D. Godín  32      90  125000
#          42              S. Umtiti  24      87  205000
#          73             M. Benatia  31      86  160000
#          89            N. Otamendi  30      85  170000
#          102                 Naldo  35      85   38000
# CDM      20        Sergio Busquets  29      89  315000
#          27               Casemiro  26      88  285000
#          72              M. Pjanić  28      86  180000
#          75            Fernandinho  33      86  185000
#          118               Fabinho  24      84  120000
# CF       271          Luis Alberto  25      82   67000
# ...

# %%
df5["Wage"]=df5['Wage'].astype(float)

# %%
df5.reset_index(inplace=True)
df5
# Out:
#     Position  level_1                 Name Age Overall      Wage
# 0        CAM       17         A. Griezmann  27      89  145000.0
# 1        CAM       31           C. Eriksen  26      88  205000.0
# 2        CAM       61      Roberto Firmino  26      86  195000.0
# 3        CAM       66            T. Müller  28      86  135000.0
# 4        CAM       74              M. Özil  29      86  190000.0
# 5         CB       12             D. Godín  32      90  125000.0
# 6         CB       42            S. Umtiti  24      87  205000.0
# 7         CB       73           M. Benatia  31      86  160000.0
# 8         CB       89          N. Otamendi  30      85  170000.0
# 9         CB      102                Naldo  35      85   38000.0
# 10       CDM       20      Sergio Busquets  29      89  315000.0
# 11       CDM       27             Casemiro  26      88  285000.0
# 12       CDM       72            M. Pjanić  28      86  180000.0
# ...

# %%
df5.groupby('Position')['Wage'].mean()
# Out:
# Position
# CAM    174000.0
# CB     139600.0
# CDM    217000.0
# CF      47400.0
# CM     130600.0
# GK     192800.0
# LAM     81600.0
# LB     177200.0
# LCB    162000.0
# LCM    184400.0
# LDM    126600.0
# LF     121200.0
# LM     164600.0
# LS     130200.0
# LW     261000.0
# LWB     34200.0
# RAM     45400.0
# RB     155400.0
# RCB    231000.0
# RCM    240800.0
# RDM    105000.0
# RF     148000.0
# RM     131400.0
# RS     132200.0
# RW     202000.0
# RWB     44200.0
# ST     294000.0
# Name: Wage, dtype: float64
