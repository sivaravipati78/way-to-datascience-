# %% [raw]
#
# age age in years
# sex(1 = male; 0 = female)
# cp-chest pain type
# trestbpsresting blood pressure (in mm Hg on admission to the hospital)
# cholserum cholestoral in mg/dl
# fbs(fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# restecgresting electrocardiographic results
# thalachmaximum heart rate achieved
# exangexercise induced angina (1 = yes; 0 = no)
# oldpeakST depression induced by exercise relative to rest
# slopethe slope of the peak exercise ST segment
# canumber of major vessels (0-3) colored by flourosopy
# thal3 = normal; 6 = fixed defect; 7 = reversable defect
# target1 or 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r'C:\Users\SRK\Desktop\siva_python\Day_10\heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df[df.duplicated()==True]# only one row is duplicate
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %%
df['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
df['sex'].value_counts()# 1 male
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
# 4 type of catagories

# %%
df.count()
# Out:
# age         303
# sex         303
# cp          303
# trestbps    303
# chol        303
# fbs         303
# restecg     303
# thalach     303
# exang       303
# oldpeak     303
# slope       303
# ca          303
# thal        303
# target      303
# dtype: int64

# %%
#resting blood pressure
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()==True]# only one row is duplicate
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
plt.subplots(figsize =(15,10))
cormat = df.corr()
sns.heatmap(cormat,square =True,vmax = 0.7,annot =True)

# %% [markdown]
# # univariant analysis

# %%
#df.distplot(df['age'])
sns.distplot(df.age,kde =True,rug=True,hist =True)
# Out:
# C:\Users\SRK\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(16, 6))

sns.countplot(df.age,hue=df.sex)

# %%
#sns.barplot(df.sex,hue =df.sex)
sns.countplot(df.sex,hue=df.sex)

# %%
sns.countplot(df.target,hue=df.sex)

# %%
sns.countplot(df.thal,hue=df.sex) # blood disorder

# %%
sns.countplot(df.fbs,hue=df.sex) # blood disorder

# %% [markdown]
# #  Bivariant analysis

# %%
sns.boxplot(df.sex,df.age)

# %%
col = ['age','cp']
plt.scatter(df['age'],df['cp'])

# %%
sns.boxplot(df.cp,df.age) # chest pain

# %%
sns.boxplot(df.cp,df.thalach) # chest pain caused

# %%
plt.scatter(df.age,df.thalach) # as age increases talach decreases(max heart rate acheived)

# %%
sns.boxplot(df.slope,df.oldpeak) # chest pain caused

# %%
plt.scatter(df.ca,df.age)

# %%
sns.boxplot(df.ca,df.age) # chest pain caused

# %%
sns.set()
#sns.pairplot(df)
cols =['age','trestbps','chol','sex','exang','target']
sns.pairplot(df[cols],height =2.5,hue ='sex')
plt.show()
# As age increases trestbps increases after 50

# %%
age = df['age']
chol = df['chol']

plt.plot(age,chol,marker='o',color ='r',df)
# Out:
#   File "<ipython-input-26-ac2dfcd6dfc1>", line 4
#     plt.plot(age,chol,marker='o',color ='r',df)
#                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.set()
#sns.pairplot(df)
#cols =['LotFrontage','LotArea','MasVnrArea']
sns.pairplot(df[df.target==1],height =2.5)
plt.show()

# %%
plt.subplots(figsize =(15,10))
cormat = df.corr()
sns.heatmap(cormat,square =True,vmax = 0.7,annot =True)

# %%
plt.subplots(figsize =(15,10))
cormat = df[df.target==0].corr()
sns.heatmap(cormat,square =True,vmax = 0.7,annot =True)
